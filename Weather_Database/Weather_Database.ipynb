# %% [markdown]
# # API Challenge
# ## Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Starting URL for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an endpoint URL for a city.
city_url = url + "&q=" + cities[0]

# Make a request
city_weather = requests.get(city_url)

# get the json
city_weather.json()
# Out:
# {'coord': {'lon': -139.0333, 'lat': -9.8},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 77.79,
#   'feels_like': 78.42,
#   'temp_min': 77.79,
#   'temp_max': 77.79,
#   'pressure': 1013,
#   'humidity': 67,
#   'sea_level': 1013,
#   'grnd_level': 1005},
#  'visibility': 10000,
#  'wind': {'speed': 23.35, 'deg': 106, 'gust': 23.87},
#  'clouds': {'all': 50},
#  'dt': 1627339948,
#  'sys': {'country': 'PF', 'sunrise': 1627313569, 'sunset': 1627355533},
#  'timezone': -34200,
#  'id': 4020109,
#  'name': 'Atuona',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = [sub['description'] for sub in city_weather['weather']]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description[0]})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | fort saint james
# Processing Record 5 of Set 1 | palauig
# Processing Record 6 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 1 | vila do maio
# Processing Record 8 of Set 1 | tokur
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | silver city
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | mecca
# Processing Record 17 of Set 1 | leningradskiy
# Processing Record 18 of Set 1 | christchurch
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | arlit
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | kokopo
# Processing Record 29 of Set 1 | oulu
# Processing Record 30 of Set 1 | okhotsk
# Processing Record 31 of Set 1 | bengkulu
# Processing Record 32 of Set 1 | dicabisagan
# Processing Record 33 of Set 1 | olafsvik
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | bonfim
# Processing Record 36 of Set 1 | pasighat
# Processing Record 37 of Set 1 | svetlyy
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | sistranda
# Processing Record 40 of Set 1 | taoudenni
# Processing Record 41 of Set 1 | huaihua
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | durban
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | luanda
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | xai-xai
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | la ronge
# Processing Record 5 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 2 | asau
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | arman
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | guaymas
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | seoul
# Processing Record 14 of Set 2 | bahia blanca
# Processing Record 15 of Set 2 | hovd
# Processing Record 16 of Set 2 | santa isabel do rio negro
# Processing Record 17 of Set 2 | rawson
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | varska
# City not found. Skipping...
# Processing Record 20 of Set 2 | verdalsora
# City not found. Skipping...
# Processing Record 21 of Set 2 | oktyabrskiy
# Processing Record 22 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 2 | dire
# Processing Record 24 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | yinchuan
# Processing Record 27 of Set 2 | fukue
# Processing Record 28 of Set 2 | grindavik
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | palu
# Processing Record 32 of Set 2 | xining
# Processing Record 33 of Set 2 | carbondale
# Processing Record 34 of Set 2 | monatele
# City not found. Skipping...
# Processing Record 35 of Set 2 | shizunai
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | urdoma
# Processing Record 38 of Set 2 | hay river
# Processing Record 39 of Set 2 | kaitangata
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | flin flon
# Processing Record 43 of Set 2 | saint-pierre
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | kutum
# Processing Record 48 of Set 2 | tucurui
# Processing Record 49 of Set 2 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 50 of Set 2 | baft
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | boyolangu
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | batagay
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 11 of Set 3 | klaksvik
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | mount hagen
# Processing Record 14 of Set 3 | itoman
# Processing Record 15 of Set 3 | husavik
# Processing Record 16 of Set 3 | adrar
# Processing Record 17 of Set 3 | hearst
# Processing Record 18 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 3 | dunedin
# Processing Record 20 of Set 3 | wukari
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | balabac
# Processing Record 23 of Set 3 | namatanai
# Processing Record 24 of Set 3 | aleksandrov gay
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | puri
# Processing Record 27 of Set 3 | ponta do sol
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 3 | vytegra
# Processing Record 31 of Set 3 | cayenne
# Processing Record 32 of Set 3 | flinders
# Processing Record 33 of Set 3 | puerto leguizamo
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | portree
# Processing Record 36 of Set 3 | changde
# Processing Record 37 of Set 3 | puerto ayora
# Processing Record 38 of Set 3 | riga
# Processing Record 39 of Set 3 | vardo
# Processing Record 40 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 3 | weligama
# Processing Record 42 of Set 3 | upernavik
# Processing Record 43 of Set 3 | buenos aires
# Processing Record 44 of Set 3 | port blair
# Processing Record 45 of Set 3 | gamba
# Processing Record 46 of Set 3 | mount gambier
# Processing Record 47 of Set 3 | conde
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | gat
# Processing Record 50 of Set 3 | lavrentiya
# Processing Record 1 of Set 4 | kiama
# Processing Record 2 of Set 4 | sinjai
# Processing Record 3 of Set 4 | sept-iles
# Processing Record 4 of Set 4 | codrington
# Processing Record 5 of Set 4 | beyneu
# Processing Record 6 of Set 4 | crown point
# Processing Record 7 of Set 4 | vilhena
# Processing Record 8 of Set 4 | ruteng
# Processing Record 9 of Set 4 | portland
# Processing Record 10 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 4 | salalah
# Processing Record 12 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | muisne
# Processing Record 15 of Set 4 | ancud
# Processing Record 16 of Set 4 | richmond
# Processing Record 17 of Set 4 | los llanos de aridane
# Processing Record 18 of Set 4 | upata
# Processing Record 19 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 4 | qaanaaq
# Processing Record 21 of Set 4 | maymanak
# City not found. Skipping...
# Processing Record 22 of Set 4 | mamallapuram
# Processing Record 23 of Set 4 | svetlogorsk
# Processing Record 24 of Set 4 | buraydah
# Processing Record 25 of Set 4 | ayios matthaios
# City not found. Skipping...
# Processing Record 26 of Set 4 | gornyye klyuchi
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | mitsamiouli
# Processing Record 30 of Set 4 | pampa
# Processing Record 31 of Set 4 | kununurra
# Processing Record 32 of Set 4 | dawlatabad
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 35 of Set 4 | okha
# Processing Record 36 of Set 4 | japura
# Processing Record 37 of Set 4 | iqaluit
# Processing Record 38 of Set 4 | williams lake
# Processing Record 39 of Set 4 | listvyagi
# Processing Record 40 of Set 4 | nome
# Processing Record 41 of Set 4 | khawhai
# Processing Record 42 of Set 4 | elko
# Processing Record 43 of Set 4 | olavarria
# Processing Record 44 of Set 4 | madulao
# Processing Record 45 of Set 4 | kuytun
# Processing Record 46 of Set 4 | berlevag
# Processing Record 47 of Set 4 | lensk
# Processing Record 48 of Set 4 | gondanglegi
# Processing Record 49 of Set 4 | avarua
# Processing Record 50 of Set 4 | casper
# Processing Record 1 of Set 5 | katobu
# Processing Record 2 of Set 5 | komsomolskiy
# Processing Record 3 of Set 5 | denpasar
# Processing Record 4 of Set 5 | altay
# Processing Record 5 of Set 5 | general roca
# Processing Record 6 of Set 5 | mogadishu
# Processing Record 7 of Set 5 | tuatapere
# Processing Record 8 of Set 5 | edgewater
# Processing Record 9 of Set 5 | bilibino
# Processing Record 10 of Set 5 | dzaoudzi
# Processing Record 11 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 5 | port elizabeth
# Processing Record 13 of Set 5 | asosa
# Processing Record 14 of Set 5 | bangaon
# Processing Record 15 of Set 5 | hirara
# Processing Record 16 of Set 5 | point pedro
# Processing Record 17 of Set 5 | arvi
# Processing Record 18 of Set 5 | itarema
# Processing Record 19 of Set 5 | yulara
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | araouane
# Processing Record 22 of Set 5 | shihezi
# Processing Record 23 of Set 5 | baykit
# Processing Record 24 of Set 5 | conceicao do mato dentro
# Processing Record 25 of Set 5 | constitucion
# Processing Record 26 of Set 5 | ustyuzhna
# Processing Record 27 of Set 5 | saint-joseph
# Processing Record 28 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 5 | sisimiut
# Processing Record 31 of Set 5 | ambunti
# Processing Record 32 of Set 5 | barra da estiva
# Processing Record 33 of Set 5 | airai
# Processing Record 34 of Set 5 | reoti
# Processing Record 35 of Set 5 | bonavista
# Processing Record 36 of Set 5 | the valley
# Processing Record 37 of Set 5 | naze
# Processing Record 38 of Set 5 | esperance
# Processing Record 39 of Set 5 | cockburn town
# Processing Record 40 of Set 5 | monte cristi
# City not found. Skipping...
# Processing Record 41 of Set 5 | methoni
# Processing Record 42 of Set 5 | elizabeth city
# Processing Record 43 of Set 5 | cairns
# Processing Record 44 of Set 5 | dhidhdhoo
# Processing Record 45 of Set 5 | torbay
# Processing Record 46 of Set 5 | aykhal
# Processing Record 47 of Set 5 | ahuimanu
# Processing Record 48 of Set 5 | touros
# Processing Record 49 of Set 5 | yar-sale
# Processing Record 50 of Set 5 | dalvik
# Processing Record 1 of Set 6 | port shepstone
# Processing Record 2 of Set 6 | juba
# Processing Record 3 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 4 of Set 6 | sola
# Processing Record 5 of Set 6 | zhezkazgan
# Processing Record 6 of Set 6 | guane
# Processing Record 7 of Set 6 | zhigansk
# Processing Record 8 of Set 6 | cahors
# Processing Record 9 of Set 6 | santa cruz
# Processing Record 10 of Set 6 | mont-de-marsan
# Processing Record 11 of Set 6 | prudnik
# Processing Record 12 of Set 6 | hambantota
# Processing Record 13 of Set 6 | kerema
# Processing Record 14 of Set 6 | soyo
# Processing Record 15 of Set 6 | kazerun
# Processing Record 16 of Set 6 | jackson
# Processing Record 17 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 18 of Set 6 | alexandria
# Processing Record 19 of Set 6 | khandagayty
# Processing Record 20 of Set 6 | minuri
# Processing Record 21 of Set 6 | dolores
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | aquiraz
# Processing Record 24 of Set 6 | carutapera
# Processing Record 25 of Set 6 | gazojak
# Processing Record 26 of Set 6 | ryotsu
# Processing Record 27 of Set 6 | wajima
# Processing Record 28 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 6 | guerrero negro
# Processing Record 30 of Set 6 | tangshan
# Processing Record 31 of Set 6 | port macquarie
# Processing Record 32 of Set 6 | panama city
# Processing Record 33 of Set 6 | mahebourg
# Processing Record 34 of Set 6 | butembo
# Processing Record 35 of Set 6 | batemans bay
# Processing Record 36 of Set 6 | ewa beach
# Processing Record 37 of Set 6 | den helder
# Processing Record 38 of Set 6 | otane
# Processing Record 39 of Set 6 | daru
# Processing Record 40 of Set 6 | gongzhuling
# Processing Record 41 of Set 6 | ayan
# Processing Record 42 of Set 6 | severnyy
# Processing Record 43 of Set 6 | port moresby
# Processing Record 44 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 45 of Set 6 | hammerfest
# Processing Record 46 of Set 6 | bay roberts
# Processing Record 47 of Set 6 | san andres
# Processing Record 48 of Set 6 | liverpool
# Processing Record 49 of Set 6 | the pas
# Processing Record 50 of Set 6 | paita
# Processing Record 1 of Set 7 | hutchinson
# Processing Record 2 of Set 7 | qaqortoq
# Processing Record 3 of Set 7 | sao filipe
# Processing Record 4 of Set 7 | bethel
# Processing Record 5 of Set 7 | tampilisan
# Processing Record 6 of Set 7 | presidencia roque saenz pena
# Processing Record 7 of Set 7 | arraial do cabo
# Processing Record 8 of Set 7 | san luis
# Processing Record 9 of Set 7 | port hedland
# Processing Record 10 of Set 7 | kruisfontein
# Processing Record 11 of Set 7 | champerico
# Processing Record 12 of Set 7 | mahajanga
# Processing Record 13 of Set 7 | marsh harbour
# Processing Record 14 of Set 7 | zhuhai
# Processing Record 15 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 7 | chowchilla
# Processing Record 17 of Set 7 | gushikawa
# Processing Record 18 of Set 7 | marienburg
# Processing Record 19 of Set 7 | pemangkat
# Processing Record 20 of Set 7 | xiashi
# Processing Record 21 of Set 7 | zhangye
# Processing Record 22 of Set 7 | poum
# Processing Record 23 of Set 7 | henties bay
# Processing Record 24 of Set 7 | hofn
# Processing Record 25 of Set 7 | narsaq
# Processing Record 26 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 7 | santo amaro da imperatriz
# Processing Record 28 of Set 7 | quthing
# Processing Record 29 of Set 7 | souillac
# Processing Record 30 of Set 7 | winnemucca
# Processing Record 31 of Set 7 | ahipara
# Processing Record 32 of Set 7 | prado
# Processing Record 33 of Set 7 | tamiahua
# Processing Record 34 of Set 7 | hegra
# Processing Record 35 of Set 7 | ximei
# Processing Record 36 of Set 7 | tocopilla
# Processing Record 37 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 7 | vao
# Processing Record 40 of Set 7 | goderich
# Processing Record 41 of Set 7 | da lat
# Processing Record 42 of Set 7 | belgrade
# Processing Record 43 of Set 7 | makakilo city
# Processing Record 44 of Set 7 | kahului
# Processing Record 45 of Set 7 | pacific grove
# Processing Record 46 of Set 7 | uray
# Processing Record 47 of Set 7 | orbetello
# Processing Record 48 of Set 7 | jiupu
# Processing Record 49 of Set 7 | kysyl-syr
# Processing Record 50 of Set 7 | sur
# Processing Record 1 of Set 8 | fort wellington
# Processing Record 2 of Set 8 | magdalena
# Processing Record 3 of Set 8 | agvali
# Processing Record 4 of Set 8 | kavieng
# Processing Record 5 of Set 8 | samarai
# Processing Record 6 of Set 8 | savannah bight
# Processing Record 7 of Set 8 | moissala
# Processing Record 8 of Set 8 | chillan
# Processing Record 9 of Set 8 | port augusta
# Processing Record 10 of Set 8 | tommot
# Processing Record 11 of Set 8 | hervey bay
# Processing Record 12 of Set 8 | jiuquan
# Processing Record 13 of Set 8 | sao paulo de olivenca
# Processing Record 14 of Set 8 | zyryanka
# Processing Record 15 of Set 8 | pendleton
# Processing Record 16 of Set 8 | hasaki
# Processing Record 17 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 8 | puerto madryn
# Processing Record 19 of Set 8 | tandil
# Processing Record 20 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 21 of Set 8 | lompoc
# Processing Record 22 of Set 8 | buala
# Processing Record 23 of Set 8 | castanos
# Processing Record 24 of Set 8 | alofi
# Processing Record 25 of Set 8 | palmer
# Processing Record 26 of Set 8 | bahia honda
# Processing Record 27 of Set 8 | ilulissat
# Processing Record 28 of Set 8 | varhaug
# Processing Record 29 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 8 | martapura
# Processing Record 31 of Set 8 | rocha
# Processing Record 32 of Set 8 | katherine
# Processing Record 33 of Set 8 | ust-omchug
# Processing Record 34 of Set 8 | wilmington
# Processing Record 35 of Set 8 | faanui
# Processing Record 36 of Set 8 | dwarka
# Processing Record 37 of Set 8 | macusani
# Processing Record 38 of Set 8 | murgab
# Processing Record 39 of Set 8 | luwuk
# Processing Record 40 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 8 | pangkalanbuun
# Processing Record 42 of Set 8 | honggang
# Processing Record 43 of Set 8 | nabire
# Processing Record 44 of Set 8 | porto novo
# Processing Record 45 of Set 8 | laguna
# Processing Record 46 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 8 | vila franca do campo
# Processing Record 49 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 50 of Set 8 | praia da vitoria
# Processing Record 1 of Set 9 | saldanha
# Processing Record 2 of Set 9 | comodoro rivadavia
# Processing Record 3 of Set 9 | fort nelson
# Processing Record 4 of Set 9 | amur
# Processing Record 5 of Set 9 | norman wells
# Processing Record 6 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 9 | tiznit
# Processing Record 8 of Set 9 | kirkwall
# Processing Record 9 of Set 9 | bay city
# Processing Record 10 of Set 9 | peniche
# Processing Record 11 of Set 9 | tecoanapa
# Processing Record 12 of Set 9 | huarmey
# Processing Record 13 of Set 9 | pavullo nel frignano
# Processing Record 14 of Set 9 | nioro
# Processing Record 15 of Set 9 | kaeo
# Processing Record 16 of Set 9 | curup
# Processing Record 17 of Set 9 | shenjiamen
# Processing Record 18 of Set 9 | cotija
# City not found. Skipping...
# Processing Record 19 of Set 9 | puerto pinasco
# City not found. Skipping...
# Processing Record 20 of Set 9 | pevek
# Processing Record 21 of Set 9 | viedma
# Processing Record 22 of Set 9 | omboue
# Processing Record 23 of Set 9 | setubal
# Processing Record 24 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 9 | kungurtug
# Processing Record 26 of Set 9 | acapulco
# Processing Record 27 of Set 9 | lima
# Processing Record 28 of Set 9 | faya
# Processing Record 29 of Set 9 | khani
# Processing Record 30 of Set 9 | nuuk
# Processing Record 31 of Set 9 | oranjemund
# Processing Record 32 of Set 9 | umm lajj
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 35 of Set 9 | la paz
# Processing Record 36 of Set 9 | kirensk
# Processing Record 37 of Set 9 | verkhniy baskunchak
# Processing Record 38 of Set 9 | tsagan aman
# Processing Record 39 of Set 9 | merauke
# Processing Record 40 of Set 9 | evora
# Processing Record 41 of Set 9 | port lincoln
# Processing Record 42 of Set 9 | serramanna
# Processing Record 43 of Set 9 | honningsvag
# Processing Record 44 of Set 9 | nemuro
# Processing Record 45 of Set 9 | pochutla
# Processing Record 46 of Set 9 | port-gentil
# Processing Record 47 of Set 9 | lins
# Processing Record 48 of Set 9 | bathsheba
# Processing Record 49 of Set 9 | pokrovka
# Processing Record 50 of Set 9 | balkanabat
# Processing Record 1 of Set 10 | vung tau
# Processing Record 2 of Set 10 | emerald
# Processing Record 3 of Set 10 | kholuy
# Processing Record 4 of Set 10 | salinopolis
# Processing Record 5 of Set 10 | isiro
# Processing Record 6 of Set 10 | kasongo-lunda
# Processing Record 7 of Set 10 | siocon
# Processing Record 8 of Set 10 | moen
# Processing Record 9 of Set 10 | boende
# Processing Record 10 of Set 10 | piacabucu
# Processing Record 11 of Set 10 | ternate
# Processing Record 12 of Set 10 | caravelas
# Processing Record 13 of Set 10 | mazamari
# Processing Record 14 of Set 10 | contai
# Processing Record 15 of Set 10 | soubre
# Processing Record 16 of Set 10 | touba
# Processing Record 17 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 18 of Set 10 | labuhan
# Processing Record 19 of Set 10 | caohai
# Processing Record 20 of Set 10 | puerto el triunfo
# Processing Record 21 of Set 10 | bud
# Processing Record 22 of Set 10 | sitka
# Processing Record 23 of Set 10 | pareora
# Processing Record 24 of Set 10 | dali
# Processing Record 25 of Set 10 | xuddur
# Processing Record 26 of Set 10 | ndouci
# City not found. Skipping...
# Processing Record 27 of Set 10 | yelizovo
# Processing Record 28 of Set 10 | pozo colorado
# Processing Record 29 of Set 10 | ambanja
# Processing Record 30 of Set 10 | yatou
# Processing Record 31 of Set 10 | ribas do rio pardo
# Processing Record 32 of Set 10 | rovaniemi
# Processing Record 33 of Set 10 | shawinigan
# Processing Record 34 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 10 | angoche
# Processing Record 36 of Set 10 | katsuura
# Processing Record 37 of Set 10 | cabo san lucas
# Processing Record 38 of Set 10 | kota tinggi
# Processing Record 39 of Set 10 | san cristobal
# Processing Record 40 of Set 10 | nichinan
# Processing Record 41 of Set 10 | afonso claudio
# Processing Record 42 of Set 10 | harper
# Processing Record 43 of Set 10 | saint george
# Processing Record 44 of Set 10 | aklavik
# Processing Record 45 of Set 10 | yumen
# Processing Record 46 of Set 10 | mastic beach
# Processing Record 47 of Set 10 | wexford
# Processing Record 48 of Set 10 | dalbandin
# Processing Record 49 of Set 10 | dahanu
# Processing Record 50 of Set 10 | armidale
# Processing Record 1 of Set 11 | riberalta
# Processing Record 2 of Set 11 | sinnamary
# Processing Record 3 of Set 11 | capoterra
# Processing Record 4 of Set 11 | malakal
# Processing Record 5 of Set 11 | honiara
# Processing Record 6 of Set 11 | bage
# Processing Record 7 of Set 11 | porangatu
# Processing Record 8 of Set 11 | bontang
# Processing Record 9 of Set 11 | aswan
# Processing Record 10 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 12 of Set 11 | watsa
# Processing Record 13 of Set 11 | alyangula
# Processing Record 14 of Set 11 | tenenkou
# Processing Record 15 of Set 11 | port hardy
# Processing Record 16 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 11 | boden
# Processing Record 18 of Set 11 | lusaka
# Processing Record 19 of Set 11 | erzin
# Processing Record 20 of Set 11 | irbil
# Processing Record 21 of Set 11 | novobirilyussy
# Processing Record 22 of Set 11 | polyarnyy
# Processing Record 23 of Set 11 | lagoa
# Processing Record 24 of Set 11 | chapais
# Processing Record 25 of Set 11 | namibe
# Processing Record 26 of Set 11 | riyadh
# Processing Record 27 of Set 11 | moron
# Processing Record 28 of Set 11 | kangaatsiaq
# Processing Record 29 of Set 11 | clyde river
# Processing Record 30 of Set 11 | dergachi
# Processing Record 31 of Set 11 | mayor pablo lagerenza
# Processing Record 32 of Set 11 | san carlos del zulia
# Processing Record 33 of Set 11 | siguiri
# Processing Record 34 of Set 11 | moose factory
# Processing Record 35 of Set 11 | berbera
# Processing Record 36 of Set 11 | del rio
# Processing Record 37 of Set 11 | te anau
# Processing Record 38 of Set 11 | natal
# Processing Record 39 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 11 | kota kinabalu
# Processing Record 41 of Set 11 | mehamn
# Processing Record 42 of Set 11 | zhifang
# Processing Record 43 of Set 11 | loei
# Processing Record 44 of Set 11 | kirkwood
# Processing Record 45 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 11 | puerto colombia
# Processing Record 47 of Set 11 | yarmouth
# Processing Record 48 of Set 11 | shafter
# Processing Record 49 of Set 11 | saint-leu
# Processing Record 50 of Set 11 | takoradi
# Processing Record 1 of Set 12 | nguruka
# Processing Record 2 of Set 12 | omemee
# Processing Record 3 of Set 12 | kashi
# Processing Record 4 of Set 12 | srednekolymsk
# Processing Record 5 of Set 12 | vestmannaeyjar
# Processing Record 6 of Set 12 | ati
# Processing Record 7 of Set 12 | rwamagana
# Processing Record 8 of Set 12 | smithers
# Processing Record 9 of Set 12 | east millcreek
# Processing Record 10 of Set 12 | ramhormoz
# Processing Record 11 of Set 12 | korla
# Processing Record 12 of Set 12 | tucumcari
# Processing Record 13 of Set 12 | macherla
# Processing Record 14 of Set 12 | tiksi
# Processing Record 15 of Set 12 | saint andrews
# Processing Record 16 of Set 12 | teguldet
# Processing Record 17 of Set 12 | nadym
# Processing Record 18 of Set 12 | kaseda
# Processing Record 19 of Set 12 | ilo
# Processing Record 20 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 12 | bilma
# Processing Record 22 of Set 12 | half moon bay
# Processing Record 23 of Set 12 | olinda
# Processing Record 24 of Set 12 | datong
# Processing Record 25 of Set 12 | vanimo
# Processing Record 26 of Set 12 | lloro
# Processing Record 27 of Set 12 | khargapur
# Processing Record 28 of Set 12 | luba
# Processing Record 29 of Set 12 | cabedelo
# Processing Record 30 of Set 12 | tabou
# Processing Record 31 of Set 12 | khorixas
# Processing Record 32 of Set 12 | kalmunai
# Processing Record 33 of Set 12 | dakar
# Processing Record 34 of Set 12 | bethanien
# Processing Record 35 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 12 | phalaborwa
# Processing Record 37 of Set 12 | jiexiu
# Processing Record 38 of Set 12 | jutai
# Processing Record 39 of Set 12 | prince george
# Processing Record 40 of Set 12 | valparaiso
# Processing Record 41 of Set 12 | chilca
# Processing Record 42 of Set 12 | turmalina
# Processing Record 43 of Set 12 | liberia
# Processing Record 44 of Set 12 | mount isa
# Processing Record 45 of Set 12 | bardiyah
# Processing Record 46 of Set 12 | encruzilhada do sul
# Processing Record 47 of Set 12 | tautira
# Processing Record 48 of Set 12 | jining
# Processing Record 49 of Set 12 | matay
# Processing Record 50 of Set 12 | tuensang
# Processing Record 1 of Set 13 | nelson bay
# Processing Record 2 of Set 13 | innisfail
# Processing Record 3 of Set 13 | tilaran
# Processing Record 4 of Set 13 | bandarbeyla
# Processing Record 5 of Set 13 | tsabong
# Processing Record 6 of Set 13 | fairbanks
# Processing Record 7 of Set 13 | ambilobe
# Processing Record 8 of Set 13 | oriximina
# Processing Record 9 of Set 13 | maua
# Processing Record 10 of Set 13 | vynohradove
# Processing Record 11 of Set 13 | bosaso
# Processing Record 12 of Set 13 | ivanava
# Processing Record 13 of Set 13 | mende
# Processing Record 14 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 15 of Set 13 | ubinskoye
# Processing Record 16 of Set 13 | razdolnoye
# Processing Record 17 of Set 13 | dudinka
# Processing Record 18 of Set 13 | santa cruz de la palma
# Processing Record 19 of Set 13 | ixtapa
# Processing Record 20 of Set 13 | saint-augustin
# Processing Record 21 of Set 13 | mandera
# Processing Record 22 of Set 13 | ponta delgada
# Processing Record 23 of Set 13 | chimore
# Processing Record 24 of Set 13 | baker city
# Processing Record 25 of Set 13 | monteiro
# Processing Record 26 of Set 13 | krasnoyarka
# Processing Record 27 of Set 13 | pocatello
# Processing Record 28 of Set 13 | chaykovskiy
# Processing Record 29 of Set 13 | qeshm
# Processing Record 30 of Set 13 | panino
# Processing Record 31 of Set 13 | beidao
# Processing Record 32 of Set 13 | ambon
# Processing Record 33 of Set 13 | westport
# Processing Record 34 of Set 13 | shelburne
# Processing Record 35 of Set 13 | constantine
# Processing Record 36 of Set 13 | talnakh
# Processing Record 37 of Set 13 | shache
# Processing Record 38 of Set 13 | eston
# Processing Record 39 of Set 13 | nouadhibou
# Processing Record 40 of Set 13 | rio cuarto
# Processing Record 41 of Set 13 | pervomayskoye
# Processing Record 42 of Set 13 | zhanaozen
# Processing Record 43 of Set 13 | labelle
# Processing Record 44 of Set 13 | qasigiannguit
# Processing Record 45 of Set 13 | almansa
# Processing Record 46 of Set 13 | suzhou
# Processing Record 47 of Set 13 | aljezur
# Processing Record 48 of Set 13 | bac lieu
# Processing Record 49 of Set 13 | padang
# Processing Record 50 of Set 13 | tatawin
# Processing Record 1 of Set 14 | elk city
# Processing Record 2 of Set 14 | colesville
# Processing Record 3 of Set 14 | alta floresta
# Processing Record 4 of Set 14 | hami
# Processing Record 5 of Set 14 | jodhpur
# Processing Record 6 of Set 14 | aborlan
# Processing Record 7 of Set 14 | labytnangi
# Processing Record 8 of Set 14 | stephenville
# Processing Record 9 of Set 14 | djambala
# Processing Record 10 of Set 14 | anito
# Processing Record 11 of Set 14 | bandar-e lengeh
# Processing Record 12 of Set 14 | lorengau
# Processing Record 13 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 14 of Set 14 | beloha
# Processing Record 15 of Set 14 | ouadda
# Processing Record 16 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 14 | opuwo
# Processing Record 18 of Set 14 | nara
# Processing Record 19 of Set 14 | saint-georges
# Processing Record 20 of Set 14 | kursk
# Processing Record 21 of Set 14 | xifeng
# Processing Record 22 of Set 14 | taksimo
# Processing Record 23 of Set 14 | hokitika
# Processing Record 24 of Set 14 | riosucio
# Processing Record 25 of Set 14 | sambava
# Processing Record 26 of Set 14 | omsukchan
# Processing Record 27 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 28 of Set 14 | antipovka
# Processing Record 29 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 14 | keffi
# Processing Record 31 of Set 14 | leshukonskoye
# Processing Record 32 of Set 14 | barguzin
# Processing Record 33 of Set 14 | crab hill
# City not found. Skipping...
# Processing Record 34 of Set 14 | beringovskiy
# Processing Record 35 of Set 14 | byron bay
# Processing Record 36 of Set 14 | bara
# Processing Record 37 of Set 14 | lasa
# Processing Record 38 of Set 14 | boa vista
# Processing Record 39 of Set 14 | hluti
# Processing Record 40 of Set 14 | mathbaria
# Processing Record 41 of Set 14 | hobyo
# Processing Record 42 of Set 14 | uyuni
# Processing Record 43 of Set 14 | bantry
# Processing Record 44 of Set 14 | margate
# Processing Record 45 of Set 14 | matara
# Processing Record 46 of Set 14 | bartica
# Processing Record 47 of Set 14 | bitung
# Processing Record 48 of Set 14 | murgud
# Processing Record 49 of Set 14 | huntsville
# Processing Record 50 of Set 14 | bushehr
# Processing Record 1 of Set 15 | qandala
# Processing Record 2 of Set 15 | faro
# Processing Record 3 of Set 15 | santa luzia
# Processing Record 4 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 15 | ust-tsilma
# Processing Record 6 of Set 15 | stornoway
# Processing Record 7 of Set 15 | bela
# Processing Record 8 of Set 15 | bati
# Processing Record 9 of Set 15 | povenets
# Processing Record 10 of Set 15 | pangody
# Processing Record 11 of Set 15 | sao joao da barra
# Processing Record 12 of Set 15 | madang
# Processing Record 13 of Set 15 | keti bandar
# Processing Record 14 of Set 15 | svetlaya
# Processing Record 15 of Set 15 | autazes
# Processing Record 16 of Set 15 | ca mau
# Processing Record 17 of Set 15 | rasht
# Processing Record 18 of Set 15 | dong hoi
# Processing Record 19 of Set 15 | koutsouras
# Processing Record 20 of Set 15 | broome
# Processing Record 21 of Set 15 | juneau
# Processing Record 22 of Set 15 | bantou
# Processing Record 23 of Set 15 | porbandar
# Processing Record 24 of Set 15 | camacha
# Processing Record 25 of Set 15 | dingle
# Processing Record 26 of Set 15 | mattru
# Processing Record 27 of Set 15 | aripuana
# Processing Record 28 of Set 15 | santa rosa
# Processing Record 29 of Set 15 | birjand
# Processing Record 30 of Set 15 | suihua
# Processing Record 31 of Set 15 | mabaruma
# Processing Record 32 of Set 15 | fortuna
# Processing Record 33 of Set 15 | horsham
# Processing Record 34 of Set 15 | sexsmith
# Processing Record 35 of Set 15 | churapcha
# Processing Record 36 of Set 15 | charters towers
# Processing Record 37 of Set 15 | magaria
# Processing Record 38 of Set 15 | lahij
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 674

# %%
# Convert to dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# %%
# Export as csv file
output_data_file = "WeatherPy_DataBase.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
